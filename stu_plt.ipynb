# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


import src.STU_2hdms as stu
import matplotlib as mpl

# %%
a2 = 0.0
a4 = 0.0
mas = 800
mutild = 800


def stu_cont(x,y):

    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - ba)
    stu.STUchk(mutild, 125, x, mutild, mas, mutild, tb, a1, a2, y, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

mh3 = np.linspace(10, 2000)
a3 = np.linspace(-1.57, 1.57)

XX, YY = np.meshgrid(mh3, a3)


ba = 0.0
z = debug(cont(XX, YY))

ba = 0
a2 = 0.78
a4 = 0.0
z2 = debug(cont(XX, YY))

ba = 0
a2 = 0.0
a4 = 0.78
mas = 1500
z3 = debug(cont(XX, YY))

ba = 0.25
a2 = 0.0
a4 = 0.0
mas = 800
mutild = 1500
z4 = debug(cont(XX, YY))

fig, ax = plt.subplots()
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['tab:blue'])

# ax.contourf(XX, YY, z2, levels=[0, 7.81],alpha=0.2)
cp2 = ax.contour(XX, YY, z2, levels=[7.81], linestyles='dotted',colors=['blue'])
cp3 = ax.contour(XX, YY, z3, levels=[7.81], linestyles='dotted',colors=['red'])
cp4 = ax.contour(XX, YY, z4, levels=[7.81], linestyles='dotted',colors=['orange'])

h1,l1 = cp.legend_elements()
h2,l2 = cp2.legend_elements()
ax.legend([h1[0],h2[0]],[r'$\alpha_{HS}=0$', r'$\alpha_{HS}=\frac{\pi}{4}$'])
ax.set_xscale('log')
ax.grid()
ax.set_xlabel(r'$m_{h_S}$')
ax.set_ylabel(r'$\alpha_{hS}$')
ax.set_title(r'$m_{H^\pm}=m_H=m_A=m_{A_S}=800$ GeV, $\cos(\beta-\alpha)=\alpha_{HS}=\alpha_{AS}=0$')
# Out:
# Text(0.5, 1.0, '$m_{H^\\pm}=m_H=m_A=m_{A_S}=800$ GeV, $\\cos(\\beta-\\alpha)=\\alpha_{HS}=\\alpha_{AS}=0$')

# %%
# a2 = 0.0
a4 = 0.0
mas = 1500
mutild = 1500


def stu_cont(x,y):

    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - ba)
    stu.STUchk(mutild+x, 125, mutild+400, mutild+100, mas, mutild, tb, a1, y, 0.0, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

x = np.linspace(-1000, 100)
y = np.linspace(-1.57, 1.57,200)

XX, YY = np.meshgrid(x, y)


ba = 0.0
z = debug(cont(XX, YY))

# ba = 0
# a2 = 0.78
# a4 = 0.0
# z2 = debug(cont(XX, YY))

# ba = 0
# a2 = 0.0
# a4 = 0.78
# mas = 1500
# z3 = debug(cont(XX, YY))

# ba = 0.25
# a2 = 0.0
# a4 = 0.0
# mas = 800
# mutild = 1500
# z4 = debug(cont(XX, YY))

fig, ax = plt.subplots()
ax.contourf(XX+1500, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX+1500, YY, z, levels=[7.81], colors=['tab:blue'])

# ax.contourf(XX, YY, z2, levels=[0, 7.81],alpha=0.2)
# cp2 = ax.contour(XX, YY, z2, levels=[7.81], linestyles='dotted',colors=['blue'])
# cp3 = ax.contour(XX, YY, z3, levels=[7.81], linestyles='dotted',colors=['red'])
# cp4 = ax.contour(XX, YY, z4, levels=[7.81], linestyles='dotted',colors=['orange'])

h1,l1 = cp.legend_elements()
# h2,l2 = cp2.legend_elements()
# ax.legend([h1[0],h2[0]],[r'$\alpha_{HS}=0$', r'$\alpha_{HS}=\frac{\pi}{4}$'])
# ax.set_xscale('log')
ax.grid()
ax.set_xlabel(r'$m_{H}$')
ax.set_ylabel(r'$\alpha_{HS}$')
ax.set_title(r'$m_{H^\pm}=1.5$ TeV, $m_{h_S}=1.9$ TeV, $\cos(\beta-\alpha)=\alpha_{hS}=\alpha_{AS}=0$')
# Out:
# Text(0.5, 1.0, '$m_{H^\\pm}=1.5$ TeV, $m_{h_S}=1.9$ TeV, $\\cos(\\beta-\\alpha)=\\alpha_{hS}=\\alpha_{AS}=0$')

# %%
mutild = 1500

ma = 1500

def stu_cont(x,y):
    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - ba)
    a2 = 0.0
    a3 = 0.0
    a4 = y
    mH = mutild
    mhs = mutild
    mhp = mutild
    mas = x
    ma = 1500
    # ma = (mutild - x* np.sin(y)**2)/(np.cos(y)**2)

    stu.STUchk(mH, 125,mhs, ma, mas, mhp, tb, a1, a2, a3, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

x = np.linspace(100, 2000)
# y = np.linspace(100, 2000)
y = np.linspace(-1.57, 1.57,200)

XX, YY = np.meshgrid(x, y)

lst_cp = []
lst_lab = []


fig, ax = plt.subplots()


ba = 0.2
mutild = 1500
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['tab:blue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha}=0.2, m_{H^\pm}=1500$ GeV')

ba = 0.1
mutild = 1500
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','lightblue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['lightblue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha}=0.1, m_{H^\pm}=1500$ GeV')


mutild = 800
ba = 0.2
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','cyan']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['cyan'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha}=0.2, m_{H^\pm}=800$ GeV')


ax.legend(lst_cp, lst_lab)
ax.set_xlabel(r'$m_{A_S}$')
ax.set_ylabel(r'$\alpha_{AS}$')
ax.set_title(r'$m_{H^\pm}=m_H$, $\alpha_{hS}=\alpha_{HS}=0$')
# Out:
# Text(0.5, 1.0, '$m_{H^\\pm}=m_H$, $\\alpha_{hS}=\\alpha_{HS}=0$')

# %%
mutild = 1500


def stu_cont(x,y):
    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - y)
    # a2 = 0.0
    a3 = 0.0
    a4 = 0.0
    mH = mutild
    mhs = x
    mhp = mutild
    mas = mutild
    ma = mutild
    # ma = (mutild - x* np.sin(y)**2)/(np.cos(y)**2)

    stu.STUchk(mH, 125,mhs, ma, mas, mhp, tb, a1, a2, a3, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

x = np.linspace(10, 2000)
# y = np.linspace(100, 2000)
y = np.linspace(-0.5, 0.5)

XX, YY = np.meshgrid(x, y)

lst_cp = []
lst_lab = []


fig, ax = plt.subplots()


a2 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['tab:blue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=0$')


a2 = 0.78
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','lightblue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['lightblue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=\frac{\pi}{4}$')


a2 = 1.57
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','cyan']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['cyan'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=\frac{\pi}{2}$')


ax.legend(lst_cp, lst_lab)
ax.set_xlabel(r'$m_{H}$')
ax.set_ylabel(r'$\cos(\beta-\alpha)$')
ax.set_title(r'$m_{H^\pm}=m_A$, $\alpha_{hS}=\alpha_{AS}=0$')
# Out:
# Text(0.5, 1.0, '$m_{H^\\pm}=m_A$, $\\alpha_{hS}=\\alpha_{AS}=0$')

# %%
a2 = 0.0
a4 = 0.0
dmhs = 000
dmas = 000
mutild = 800

def stu_cont(x,y):

    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - 0.0)

    stu.STUchk(mutild+x, 125, mutild+dmhs, mutild+y, mutild+dmas, mutild, tb, a1, a2, 0.0, a4)
    return stu.STU.chi2
def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

ma = np.linspace(-700, 700, 100)
mh = np.linspace(-700, 700, 100)

XX, YY = np.meshgrid(mh, ma)


z = cont(XX, YY)
z = debug(z)



a2 =np.pi/8
z2 = cont(XX, YY)
z2 = debug(z2)



a2 =np.pi/8
a4 = 0.0
dmas = 0
dmhs = 400
z3 = cont(XX, YY)
z3 = debug(z3)

a2 =np.pi/8
a4 = 0.0
dmas = 00
dmhs = -400
z4 = debug(cont(XX, YY))

# %%
fig, ax = plt.subplots()
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.2, cmap=mpl.colors.ListedColormap(['white','blue']))
stuplt1 = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'])
ax.contourf(XX, YY, z2, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','lightskyblue']))
stuplt2 = ax.contour(XX, YY, z2, levels=[7.81], colors='lightskyblue', linestyles='dotted')
ax.contourf(XX, YY, z3, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','cyan']))
stuplt3 = ax.contour(XX, YY, z3, levels=[7.81], colors='cyan', linestyles='dashed')
ax.contourf(XX, YY, z4, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','violet']))
stuplt4 = ax.contour(XX, YY, z4, levels=[7.81], colors='violet', linestyles='dashed')

# stuplt1.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
h1,l1 = stuplt1.legend_elements()
h2,l2 = stuplt2.legend_elements()
h3,l3 = stuplt3.legend_elements()
h4,l4 = stuplt4.legend_elements()
# stuplt2.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
ax.set_xlabel('$m_H - m_{H^\pm}$')
ax.set_ylabel('$m_A - m_{H^\pm}$')

ax.legend([h1[0],h2[0], h3[0], h4[0]],[r'$m_{h_S} = m_{H^\pm},~\alpha_{HS}=0$',r'$m_{h_S}  =m_{H^\pm},~\alpha_{HS}=\frac{\pi}{4}$', r'$m_{h_S} - m_{H^\pm} = 400~\text{GeV},~\alpha_{HS}=\frac{\pi}{4}$', r'$m_{h_S} -m_{H^\pm} = -400~\text{GeV},~\alpha_{HS}=\frac{\pi}{4}$'], fontsize = 7)
plt.title(r'$\cos({\beta-\alpha})=\alpha_{hS}=\alpha_{AS}=0,~m_{H^\pm}=800$ GeV')
ax.grid()

# %%
a2 = 0.0
a4 = 0.78
dmas = 0
dmhs = 0
z12 = debug(cont(XX, YY))

a2 =0.0
a4 = 0.78
dmas = 400
dmhs = 0
z13 = debug(cont(XX, YY))

a2 =0.0
a4 = 0.78
dmas = -400
dmhs = 0
z14 = debug(cont(XX, YY))

# %%
fig, ax = plt.subplots()
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.2, cmap=mpl.colors.ListedColormap(['white','blue']))
stuplt1 = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'])
ax.contourf(XX, YY, z12, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','lightskyblue']))
stuplt2 = ax.contour(XX, YY, z12, levels=[7.81], colors='lightskyblue', linestyles='dotted')
ax.contourf(XX, YY, z13, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','cyan']))
stuplt3 = ax.contour(XX, YY, z13, levels=[7.81], colors='cyan', linestyles='dashed')
ax.contourf(XX, YY, z14, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','violet']))
stuplt4 = ax.contour(XX, YY, z14, levels=[7.81], colors='violet', linestyles='dashed')

# stuplt1.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
h1,l1 = stuplt1.legend_elements()
h2,l2 = stuplt2.legend_elements()
h3,l3 = stuplt3.legend_elements()
h4,l4 = stuplt4.legend_elements()
# stuplt2.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
ax.set_xlabel('$m_H - m_{H^\pm}$')
ax.set_ylabel('$m_A - m_{H^\pm}$')

ax.legend([h1[0],h2[0], h3[0], h4[0]],[r'$m_{A_S} = m_{H^\pm},~\alpha_{AS}=0$',r'$m_{A_S}  =m_{H^\pm},~\alpha_{AS}=\frac{\pi}{4}$', r'$m_{A_S} - m_{H^\pm} = 400~\text{GeV},~\alpha_{AS}=\frac{\pi}{4}$', r'$m_{A_S} -m_{H^\pm} = -400~\text{GeV},~\alpha_{AS}=\frac{\pi}{4}$'], fontsize = 7)
plt.title(r'$\cos({\beta-\alpha})=\alpha_{hS}=\alpha_{HS}=0,~m_{H^\pm}=800$ GeV')
ax.grid()

# %%
mutild = 800

a2 = 0.78
a4 = 0.78
dmas = 0
dmhs = 0
z22 = debug(cont(XX, YY))

a2 =0.78
a4 = 0.78
dmas = 400
dmhs = 400
z23 = debug(cont(XX, YY))

a2 =0.78
a4 = 0.78
dmas = -400
dmhs = -400
z24 = debug(cont(XX, YY))

a2 =0.78
a4 = 0.78
dmas = -400
dmhs = 400
z25 = debug(cont(XX, YY))

a2 =0.78
a4 = 0.78
dmas = 400
dmhs = -400
z26 = debug(cont(XX, YY))

# %%
fig, ax = plt.subplots()
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.2, cmap=mpl.colors.ListedColormap(['white','blue']))
stuplt1 = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'])
ax.contourf(XX, YY, z22, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','lightskyblue']))
stuplt2 = ax.contour(XX, YY, z22, levels=[7.81], colors='lightskyblue', linestyles='dotted')
ax.contourf(XX, YY, z23, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','cyan']))
stuplt3 = ax.contour(XX, YY, z23, levels=[7.81], colors='cyan', linestyles='dashed')
ax.contourf(XX, YY, z24, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','violet']))
stuplt4 = ax.contour(XX, YY, z24, levels=[7.81], colors='violet', linestyles='dashed')
# ax.contourf(XX, YY, z25, levels=[0, 7.81],alpha=0.05, cmap=mpl.colors.ListedColormap(['white','brown']))
# stuplt5 = ax.contour(XX, YY, z25, levels=[7.81], colors='brown', linestyles='dotted')
# ax.contourf(XX, YY, z26, levels=[0, 7.81],alpha=0.05, cmap=mpl.colors.ListedColormap(['white','orange']))
# stuplt6 = ax.contour(XX, YY, z26, levels=[7.81], colors='orange', linestyles='dotted')

# stuplt1.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
h1,l1 = stuplt1.legend_elements()
h2,l2 = stuplt2.legend_elements()
h3,l3 = stuplt3.legend_elements()
h4,l4 = stuplt4.legend_elements()
# stuplt2.collections[0].set_label(r'$\alpha_{HS}=\alpha_{AS}=0$')
ax.set_xlabel('$m_H$')
ax.set_ylabel('$m_A$')

ax.legend([h1[0],h2[0], h3[0], h4[0]],[r'$m_{A_S}=m_{h_S} =m_{H^\pm},~\alpha_{HS}=\alpha_{AS}=0$',r'$m_{A_S}=m_{h_S}=m_{H^\pm},~\alpha_{HS}=\alpha_{AS}=\frac{\pi}{4}$', r'$m_{A_S}=m_{h_S} = m_{H^\pm} +400~\text{GeV},~\alpha_{HS}=\alpha_{AS}=\frac{\pi}{4}$', r'$m_{A_S}=m_{h_S} =m_{H^\pm}- 400~\text{GeV},~\alpha_{HS}=\alpha_{AS}=\frac{\pi}{4}$'],fontsize=7,loc='lower right')
plt.title(r'$\cos({\beta-\alpha})=\alpha_{hS}=0,~m_{H^\pm}=800$ GeV')
ax.grid()

# %%
ba = 0.0
a2 = 0.0
a3 = 0.0
a4 = 0.0

mutild = 800

def stu_cont(x,y):

    tb = 1
    a1 = np.arctan(tb)- (np.arccos(ba))

    stu.STUchk(mutild+x, 125, mutild+y, mutild, mutild, mutild, tb, a1, a2, a3, a4)
    return stu.STU.chi2
def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

mut = np.linspace(-700, 700)
mhs = np.linspace(-700, 700)

XX, YY = np.meshgrid(mut, mhs)


lst_cp = []
lst_lab = []


fig, ax = plt.subplots()

# a2=0.78
# z = debug(cont(XX, YY))
# ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
# stuplt1 = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'])

ba = 0.0
a2 = 0.0
a3 = 0.25
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dotted')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{hS}=0.25, m_{H^\pm}=800$ GeV')

ba = 0.25
a2 = 0.0
a3 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dashed')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, m_{H^\pm}=800$ GeV')

ba = 0.25
a2 = 0.0
a3 = 0.25
a4 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dashdot')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=\alpha_{hS}=0.25, m_{H^\pm}=800$ GeV')

# ba = 0.0
# a2 = 0.78
# a3 = 0.25
# a4 = 0.0
# z = debug(cont(XX, YY))
# ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
# stuplt1 = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dashdot')
mutild = 1500
ba = 0.0
a2 = 0.0
a3 = 0.25
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dotted')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{hS}=0.25, m_{H^\pm}=1500$ GeV')

ba = 0.25
a2 = 0.0
a3 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dashed')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, m_{H^\pm}=1500$ GeV')

ba = 0.25
a2 = 0.0
a3 = 0.25
a4 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dashdot')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=\alpha_{hS}=0.25, m_{H^\pm}=1500$ GeV')

ax.legend(lst_cp, lst_lab, loc='upper left')
ax.set_xlabel('$m_H-m_{H^\pm}$')
ax.set_ylabel('$m_{h_S}-m_{H^\pm}$')

ax.set_title('$m_A=m_{H^\pm}$')
# Out:
# Text(0.5, 1.0, '$m_A=m_{H^\\pm}$')

# %%
ba = 0.0
a2 = 0.0
a3 = 0.0
a4 = 0.0

mutild = 800

def stu_cont(x,y):

    tb = 1
    a1 = np.arctan(tb)- (np.arccos( ba))

    stu.STUchk(mutild, 125, mutild, mutild+x, mutild+y, mutild, tb, a1, a2, a3, a4)
    return stu.STU.chi2
def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)

cont = np.frompyfunc(stu_cont, 2, 1)

mut = np.linspace(-700, 700)
mhs = np.linspace(-700, 700)

XX, YY = np.meshgrid(mut, mhs)


lst_cp = []
lst_lab = []
fig, ax = plt.subplots()
ba = 0.0
a4 = 0.78
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dotted')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{AS}=\frac{\pi}{4}, m_{H^\pm}=800$ GeV')

ba = 0.25
a4 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dashed')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, m_{H^\pm}=800$ GeV')

ba = 0.25
a4 = 0.78
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['blue'],linestyles='dashdot')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, \alpha_{AS}=\frac{\pi}{4}, m_{H^\pm}=800$ GeV')

mutild = 1500
ba = 0.0
a4 = 0.78
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dotted')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{AS}=\frac{\pi}{4}, m_{H^\pm}=1500$ GeV')

ba = 0.25
a4 = 0.0
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dashed')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, m_{H^\pm}=1500$ GeV')

ba = 0.25
a4 = 0.78
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.1, cmap=mpl.colors.ListedColormap(['white','red']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['red'],linestyles='dashdot')
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$c_{\beta-\alpha_{hH}}=0.25, \alpha_{AS}=\frac{\pi}{4}, m_{H^\pm}=1500$ GeV')

ax.set_xlabel('$m_A-m_{H^\pm}$')
ax.set_ylabel('$m_{A_S}-m_{H^\pm}$')

ax.set_title('$m_H=m_{H^\pm}$')

ax.legend(lst_cp, lst_lab, loc='upper right')

# %% [markdown]
# # mH- mA vs mhS -mA

# %%
mutild = 1500

def stu_cont(x,y):
    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - 0.0)
    # a2 = 0.0
    a3 = 0.0
    a4 = 0.0
    mH =  mutild+x
    mhs = mutild+y
    mhp = mutild
    mas = mutild
    ma = mutild +200
    # ma = (mutild - x* np.sin(y)**2)/(np.cos(y)**2)

    stu.STUchk(mH, 125,mhs, ma, mas, mhp, tb, a1, a2, a3, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)



x = np.linspace(-500, 500)
y = np.linspace(-500, 500)

XX, YY = np.meshgrid(x, y)

fig, ax = plt.subplots()

lst_cp = []
lst_lab = []

a2 = np.pi/4
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['tab:blue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=\frac{\pi}{4}$')

a2 = np.pi/8
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','lightblue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['lightblue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=\frac{\pi}{8}$')


a2 = 0
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','cyan']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['cyan'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{HS}=0$')

ax.legend(lst_cp, lst_lab)
ax.grid()
ax.set_xlabel('$m_H-m_{H^\pm}$')
ax.set_ylabel('$m_{h_S}-m_{H^\pm}$')
ax.set_title('$m_A-m_{H^\pm} = 200$ GeV')
# Out:
# Text(0.5, 1.0, '$m_A-m_{H^\\pm} = 200$ GeV')

# %%
mutild = 1500

def stu_cont(x,y):
    tb = 1
    a1 = np.arctan(tb)- (np.pi/2 - 0.0)
    a2 = 0.0
    a3 = 0.0
    # a4 = 0.0
    mH =  mutild+200
    mhs = mutild
    mhp = mutild
    ma = mutild+x
    mas = mutild+y
    # ma = (mutild - x* np.sin(y)**2)/(np.cos(y)**2)

    stu.STUchk(mH, 125,mhs, ma, mas, mhp, tb, a1, a2, a3, a4)
    return stu.STU.chi2

def debug(npda):
    lst = []
    for li in npda:
        lst.append(list(li))
    return(lst)



x = np.linspace(-500, 500)
y = np.linspace(-500, 500)

XX, YY = np.meshgrid(x, y)

fig, ax = plt.subplots()

lst_cp = []
lst_lab = []

a4 = np.pi/4
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','tab:blue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['tab:blue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{AS}=\frac{\pi}{4}$')

a4 = np.pi/8
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','lightblue']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['lightblue'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{AS}=\frac{\pi}{8}$')


a4 = 0
cont = np.frompyfunc(stu_cont, 2, 1)
z = debug(cont(XX, YY))
ax.contourf(XX, YY, z, levels=[0, 7.81],alpha=0.075,cmap=mpl.colors.ListedColormap(['white','cyan']))
cp = ax.contour(XX, YY, z, levels=[7.81], colors=['cyan'])
h1,l1 = cp.legend_elements()
lst_cp.append(h1[0])
lst_lab.append(r'$\alpha_{AS}=0$')

ax.legend(lst_cp, lst_lab)
ax.grid()
ax.set_xlabel('$m_A-m_{H^\pm}$')
ax.set_ylabel('$m_{A_S}-m_{H^\pm}$')
ax.set_title('$m_H-m_{H^\pm} = 200$ GeV')
# Out:
# Text(0.5, 1.0, '$m_H-m_{H^\\pm} = 200$ GeV')
